# %%
#import libraries
import yfinance as yf
import numpy as np
from matplotlib import pyplot as plt
import datetime
import pandas as pd
from IPython.display import display, clear_output
import time

# %%
#define date range
start = datetime.datetime(1990, 1, 1)
end = datetime.datetime(2021, 5, 31)
years = (end - start).days / 365.25

# %%
#define starting variables
symbols = ["^GSPC"]
systems = ["RSI"]
starting_balance = 10000
slow_ma = 200
fast_ma = 5
rsi_periods = []
rsi_periods.extend(range(2, 50, 2))
rsi_thresholds = []
rsi_thresholds.extend(range(5, 40, 2))

# %%
def get_price_data(symbol):
    #download data
    price = yf.download(symbol, start, end, progress = False)
    
    #drop redundant columns
    price = price.drop(["Volume", "Adj Close"], axis=1)
    
    return price

# %%
def calculate_inputs(df, s, rsi_period):
    #calculate inputs required for system
    
    #calculate moving averages
    df["Fast_MA"] = df.Close.rolling(window = fast_ma).mean()
    df["Slow_MA"] = df.Close.rolling(window = slow_ma).mean()
    
    #daily change
    df["Change"] = df.Close.diff()
    #separate into up and down days
    df["Gain"] = df.Change.clip(lower = 0)
    df["Loss"] = -1 * df.Change.clip(upper = 0)
    
    #average gains with EMA smoothing (Wilder)
    df[f"{s}Avg_Gain"] = ((df.Gain.shift(1) * (rsi_period - 1)) + df.Gain) / rsi_period
    df[f"{s}Avg_Loss"] = ((df.Loss.shift(1) * (rsi_period - 1)) + df.Loss) / rsi_period
    
    #relative strength
    df[f"{s}RS"] = df[f"{s}Avg_Gain"] / df[f"{s}Avg_Loss"]
    
    #RSI
    df[f"{s}RSI"] = 100 - (100 / (1 + df[f"{s}RS"]))
    
    return df

# %%
def generate_signals(df, s, rsi_thresh):
    #generate entries and exits
    if s == "BuyHold":
        df[f"{s}_Signal"] = True
    else:
        #entry is taken at the close
        df[f"{s}_Signal"] = (df[f"{s}RSI"] < rsi_thresh) & (df.Close > df.Slow_MA)

    #exit is taken at the close
    df[f"{s}_Exit"] = (df.Close > df.Fast_MA)
    
    return df

# %%
def generate_trades(df, s):
    if s == "BuyHold":
        #calculate benchmark return and balance
        df[f"{s}_Trade"] = True
        df[f"{s}_Ret"] = df.Close / df.Close.shift(1)
        df[f"{s}_Ret"].iat[0] = 1
        df[f"{s}_Bal"] = starting_balance * df[f"{s}_Ret"].cumprod()
    else:
        #create empty list for trades
        trades_list = []
        trade_open = False
        
        #iterate through rows to work out entries and exits
        for i, row in df.iterrows():
            #if there is currently no trade
            if trade_open == False:
                #check if long signal was generated at the close and enter at the same time
                if row[f"{s}_Signal"] == True:
                    entry_date = i
                    entry_price = row.Close
                    trade_open = True
            #check if a trade is already open
            elif trade_open == True:
                #check if an exit signal has been generated on today"s close and sell shares
                if row[f"{s}_Exit"] == True:
                    exit_date = i
                    exit_price = row.Close
                    trade_open = False
                    #store trade data in a list
                    trade = [entry_date, entry_price, exit_date, exit_price, True]
                    #append trade to overall trade list
                    trades_list.append(trade)
                    
        trades = pd.DataFrame(trades_list, columns = ["Entry_Date", "Entry_Price", "Exit_Date", "Exit_Price", "Sys_Trade"])
        
        #calculate return of each trade as well as the trade duration
        trades[f"{s}Return"] = trades.Exit_Price / trades.Entry_Price
        dur = []
        for i, row in trades.iterrows():
            d1 = row.Entry_Date
            d2 = row.Exit_Date
            dur.append(np.busday_count(d1.date(), d2.date()))
        
        trades[f"{s}Duration"] = dur
            
        trades.head()
    
        #create a new dataframe with an index of exit dfs
        returns = pd.DataFrame(index = trades.Exit_Date)
        
        #add the Return column to this new data frame
        returns[f"{s}_Ret"] = pd.Series(trades[f"{s}Return"]).values
        returns[f"{s}_Trade"] = pd.Series(trades.Sys_Trade).values
        returns[f"{s}Duration"] = pd.Series(trades[f"{s}Duration"]).values
    
        #add the returns from the trades to the main data frame
        df = pd.concat([df, returns], axis = 1)
    
        #fill all the NaN return values with 1 as there was no profit or loss on those days
        df[f"{s}_Ret"] = df[f"{s}_Ret"].fillna(1)
        #fill all the NaN trade values with False as there was no trade on those days
        df[f"{s}_Trade"] = df[f"{s}_Trade"].infer_objects(copy=False)
        
        #calculate system balance
        df[f"{s}_Bal"] = starting_balance * df[f"{s}_Ret"].cumprod()
    
        active_trades = np.where(df[f"{s}_Trade"] == True, True, False)
        #populate trades column based on duration
        for count, t in enumerate(active_trades):
            if t == True:
                dur = df[f"{s}Duration"].iat[count]
                for i in range(int(dur)):
                    #starting from the exit date, move backwards and mark each trading day
                    df[f"{s}_Trade"].iat[count - i] = True
    
    return df

# %%
def backtest(price, p, t):

    for s in systems:
        #calculate strategy inputs
        price = calculate_inputs(price, s, p)
        #generate signals
        price = generate_signals(price, s, t)
        #generate trades
        price = generate_trades(price, s)

    for s in systems:
        #calculate drawdown
        price[f"{s}_Peak"] = price[f"{s}_Bal"].cummax()
        price[f"{s}_DD"] = price[f"{s}_Bal"] - price[f"{s}_Peak"]

    return price

# %%
#calculate metrics
def get_metrics(system, data):
    metrics = {}
    sys_return = round(((data[f"{system}_Bal"].iloc[-1]/data[f"{system}_Bal"].iloc[0]) - 1) * 100, 2)
    sys_cagr = round(((((data[f"{system}_Bal"].iloc[-1]/data[f"{system}_Bal"].iloc[0])**(1/years))-1)*100), 2)
    sys_peak = data[f"{system}_Bal"].cummax()
    sys_dd = round(((data[f"{system}_DD"] / data[f"{system}_Peak"]).min()) * 100, 2)
    rod = sys_cagr / abs(sys_dd)
 
    win = data[f"{system}_Ret"] > 1
    loss = data[f"{system}_Ret"] < 1
    signals = data[f"{system}_Signal"].sum()
    trades_triggered = data[f"{system}_Trade"].sum()
    tim = round((trades_triggered / len(data)) * 100)
    rbe = round((sys_cagr / tim) * 100, 2)
    rbeod = rbe / abs(sys_dd) # return by exposure by drawdown (assuming drawdown doesn"t scale as TIM increases. Could be wrong)
    gaps = ((data[f"{system}_Trade"] == True) & (data.Open > data.High.shift(1))).sum()
    non_gaps = ((data[f"{system}_Trade"] == True) & (data.Open <= data.High.shift(1))).sum()
    wins = win.sum()
    losses = loss.sum()
    winrate = round(wins / (wins + losses) * 100, 2)
    
    # calculate the size of the move from the entry data to the close
    ret_size = np.where(data[f"{system}_Trade"] == True, data[f"{system}_Ret"], 1)
    avg_up_move = (data[f"{system}_Ret"][data[f"{system}_Ret"] > 1].mean() - 1) * 100
    max_up_move = (data[f"{system}_Ret"].max() - 1) * 100
    avg_down_move = (data[f"{system}_Ret"][data[f"{system}_Ret"] < 1].mean() - 1) * 100
    max_down_move = (data[f"{system}_Ret"].min() - 1) * 100
    avg_rr = round(abs(avg_up_move / avg_down_move), 2)

    #save data
    metrics["Start_Balance"] = round(data[f"{system}_Bal"].iat[0], 2)
    metrics["Final_Balance"] = round(data[f"{system}_Bal"].iat[-1], 2)
    metrics["Total_Return"] = round(sys_return, 2)
    metrics["Annual_Return"] = round(sys_cagr, 2)
    metrics["Time_in_Market"] = round(tim, 2)
    metrics["Return_By_Exposure"] = rbe
    metrics["Max_Drawdown"] = round(sys_dd, 2)
    metrics["Return_Over_Drawdown"] = round(rod, 2)
    metrics["RBE_Over_Drawdown"] = round(rbeod, 2)
    metrics["Signals"] = round(signals, 2)
    metrics["Trades"] = round(trades_triggered, 2)
    
    metrics["Gap"] = round(gaps)
    metrics["No_Gap"] = round(non_gaps)
    metrics["Wins"] = round(wins, 2)
    metrics["Losses"] = round(losses, 2)
    metrics["Winrate"] = round(winrate, 2)
    metrics["Max_Trade_Return_pct"] = round(max_up_move, 2)
    metrics["Max_Trade_Loss_pct"] = round(max_down_move, 2)
    metrics["Avg_Trade_Return_pct"] = round(avg_up_move, 2)
    metrics["Avg_Trade_Loss_pct"] = round(avg_down_move, 2)
    metrics["Avg_RR"] = avg_rr
    
    return metrics

# %%
results = []
prog = 0
max_prog = len(symbols) * len(rsi_periods) * len(rsi_thresholds)
start_time = time.time()
for sym in symbols:
    price = get_price_data(sym)
    for per in rsi_periods:
        for th in rsi_thresholds:
            result = backtest(price, per, th)
            results.append(result)
            prog += 1
            clear_output(wait=True)
            print(f"Progress: {round((prog / max_prog) * 100)} %")
end_time = time.time()
print(f"Total Time Elapsed: {end_time - start_time} s")
# Out:
# Progress: 100 %
# Total Time Elapsed: 301.34032678604126 s

# %%
full_metrics = {}
for count, res in enumerate(results):
    sys_metrics = {}
    for s in systems:
        sys_metrics.update({s: get_metrics(s, res)})
    sys_metrics_df = pd.DataFrame.from_dict(sys_metrics)
    full_metrics.update({count: sys_metrics_df})

# %%
compared_metrics = pd.DataFrame(columns=["sys", "cagr", "tim", "rbe", "max_dd", "rod", "rbeod", "winrate", "rr"])
count = 0
for per in rsi_periods:
    for th in rsi_thresholds:
        data = full_metrics[count]
        sys = f"RSI_Period_{per}_Thresh_{th}"
        cagr = data[systems[0]].loc["Annual_Return"]
        tim = data[systems[0]].loc["Time_in_Market"]
        rbe = data[systems[0]].loc["Return_By_Exposure"]
        max_dd = data[systems[0]].loc["Max_Drawdown"]
        rod = data[systems[0]].loc["Return_Over_Drawdown"]
        rbeod = data[systems[0]].loc["RBE_Over_Drawdown"]
        winrate = data[systems[0]].loc["Winrate"]
        rr = data[systems[0]].loc["Avg_RR"]
        new_row = [sys, cagr, tim, rbe, max_dd, rod, rbeod, winrate, rr]
        compared_metrics.loc[len(compared_metrics)] = new_row
        count += 1

# %%
pd.set_option('display.max_rows', None)
compared_metrics
# Out:
# 418  RSI_Period_48_Thresh_13  3.89  36.0  10.81  -28.83  0.13   0.37    67.04
# 419  RSI_Period_48_Thresh_15  3.77  36.0  10.47  -27.97  0.13   0.37    66.79
# 420  RSI_Period_48_Thresh_17  3.80  36.0  10.56  -27.97  0.14   0.38    66.61
# 421  RSI_Period_48_Thresh_19  3.75  36.0  10.42  -27.97  0.13   0.37    66.64
# 422  RSI_Period_48_Thresh_21  3.79  36.0  10.53  -27.97  0.14   0.38    66.58
# 423  RSI_Period_48_Thresh_23  3.82  36.0  10.61  -27.97  0.14   0.38    66.52
# 424  RSI_Period_48_Thresh_25  3.78  36.0  10.50  -27.97  0.14   0.38    66.19
# 425  RSI_Period_48_Thresh_27  3.77  36.0  10.47  -27.97  0.13   0.37    66.13
# 426  RSI_Period_48_Thresh_29  3.78  36.0  10.50  -27.97  0.14   0.38    66.19
# 427  RSI_Period_48_Thresh_31  3.81  36.0  10.58  -27.97  0.14   0.38    66.19
# 428  RSI_Period_48_Thresh_33  3.81  36.0  10.58  -27.97  0.14   0.38    66.16
# 429  RSI_Period_48_Thresh_35  3.82  36.0  10.61  -27.97  0.14   0.38    66.19
# 430  RSI_Period_48_Thresh_37  3.81  37.0  10.30  -27.97  0.14   0.37    66.16
# 431  RSI_Period_48_Thresh_39  3.83  37.0  10.35  -27.97  0.14   0.37    66.22
#
#        rr
# 0    0.62
# 1    0.63
# 2    0.63
# 3    0.62
# 4    0.62
# 5    0.63
# 6    0.63
# 7    0.62
# 8    0.62
# 9    0.62
# 10   0.62
# 11   0.61
# 12   0.61
# 13   0.61
# 14   0.61
# 15   0.60
# 16   0.58
# 17   0.58
# 18   0.62
# 19   0.64
# 20   0.62
# 21   0.62
# 22   0.61
# 23   0.61
# 24   0.61
# 25   0.62
# 26   0.61
# 27   0.62
# 28   0.62
# 29   0.63
# 30   0.64
# 31   0.65
# 32   0.60
# 33   0.62
# 34   0.62
# 35   0.62
# 36   0.63
# 37   0.62
# 38   0.61
# 39   0.61
# 40   0.61
# 41   0.62
# 42   0.63
# 43   0.64
# 44   0.65
# 45   0.61
# 46   0.62
# 47   0.63
# 48   0.63
# 49   0.65
# 50   0.66
# 51   0.67
# 52   0.68
# 53   0.67
# 54   0.62
# 55   0.61
# 56   0.62
# 57   0.62
# 58   0.64
# 59   0.65
# 60   0.65
# 61   0.62
# 62   0.63
# 63   0.63
# 64   0.65
# 65   0.67
# 66   0.67
# 67   0.68
# 68   0.68
# 69   0.68
# 70   0.69
# 71   0.69
# 72   0.61
# 73   0.62
# 74   0.63
# 75   0.65
# 76   0.66
# 77   0.62
# 78   0.63
# 79   0.64
# 80   0.66
# 81   0.66
# 82   0.67
# 83   0.68
# 84   0.68
# 85   0.68
# 86   0.68
# 87   0.68
# 88   0.67
# 89   0.67
# 90   0.62
# 91   0.62
# 92   0.64
# 93   0.66
# 94   0.63
# 95   0.63
# 96   0.65
# 97   0.67
# 98   0.68
# 99   0.68
# 100  0.68
# 101  0.68
# 102  0.68
# 103  0.67
# 104  0.67
# 105  0.67
# 106  0.68
# 107  0.68
# 108  0.62
# 109  0.62
# 110  0.66
# 111  0.62
# 112  0.63
# 113  0.65
# 308  0.69
# 309  0.69
# 310  0.68
# 311  0.68
# 312  0.68
# 313  0.68
# 314  0.69
# 315  0.69
# 316  0.68
# 317  0.69
# 318  0.69
# 319  0.70
# 320  0.70
# 321  0.69
# 322  0.69
# 323  0.70
# 324  0.63
# 325  0.68
# 326  0.69
# 327  0.69
# 328  0.68
# 329  0.68
# 330  0.68
# 331  0.68
# 332  0.69
# 333  0.68
# 334  0.69
# 335  0.69
# 336  0.69
# 337  0.70
# 338  0.69
# 339  0.69
# 340  0.69
# 341  0.70
# 342  0.64
# 343  0.68
# 344  0.69
# 345  0.68
# 346  0.68
# 347  0.68
# 348  0.69
# 349  0.69
# 350  0.69
# 351  0.68
# 352  0.69
# 353  0.69
# 354  0.70
# 355  0.70
# 356  0.69
# 357  0.70
# 358  0.70
# 359  0.70
# 360  0.64
# 361  0.68
# 362  0.69
# 363  0.67
# 364  0.68
# 365  0.68
# 366  0.68
# 367  0.69
# 368  0.69
# 369  0.69
# 370  0.69
# 371  0.69
# 372  0.70
# 373  0.70
# 374  0.69
# 375  0.70
# 376  0.70
# 377  0.70
# 378  0.65
# 379  0.68
# 380  0.69
# 381  0.68
# 382  0.68
# 383  0.68
# 384  0.68
# 385  0.69
# 386  0.68
# 387  0.69
# 388  0.69
# 389  0.70
# 390  0.70
# 391  0.70
# 392  0.70
# 393  0.70
# 394  0.70
# 395  0.70
# 396  0.66
# 397  0.68
# 398  0.69
# 399  0.68
# 400  0.68
# 401  0.69
# 402  0.69
# 403  0.69
# 404  0.68
# 405  0.69
# 406  0.69
# 407  0.70
# 408  0.70
# 409  0.69
# 410  0.70
# 411  0.70
# 412  0.70
# 413  0.70
# 414  0.67
# 415  0.69
# 416  0.69
# 417  0.68
# 418  0.68
# 419  0.68
# 420  0.69
# 421  0.68
# 422  0.69
# 423  0.69
# 424  0.70
# 425  0.70
# 426  0.70
# 427  0.70
# 428  0.70
# 429  0.70
# 430  0.70
# 431  0.70

# %%
plt.style.use("dark_background")
plt.rcParams["figure.figsize"] = (16,8)
plt.rcParams.update({"font.size": 10})

colours = ["tab:olive", "tab:blue", "tab:purple", "tab:orange"]

plt.xticks(rotation=90)
plt.plot(compared_metrics["sys"], compared_metrics["rod"])

plt.legend(systems)
plt.show()

# %%
for m in full_metrics:
    print(m)
    print(full_metrics[m])
# Out:
# 0
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34757.68
# Total_Return            247.58
# Annual_Return             4.05
# Time_in_Market           25.00
# Return_By_Exposure       16.20
# Max_Drawdown            -15.96
# Return_Over_Drawdown      0.25
# RBE_Over_Drawdown         1.02
# Signals                1180.00
# Trades                 1978.00
# Gap                      83.00
# No_Gap                 1895.00
# Wins                    438.00
# Losses                  167.00
# Winrate                  72.40
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.23
# Avg_RR                    0.62
# 1
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35820.81
# Total_Return            258.21
# Annual_Return             4.15
# Time_in_Market           25.00
# Return_By_Exposure       16.60
# Max_Drawdown            -16.42
# Return_Over_Drawdown      0.25
# RBE_Over_Drawdown         1.01
# Signals                1218.00
# Trades                 2015.00
# Gap                      85.00
# No_Gap                 1930.00
# Wins                    445.00
# Losses                  172.00
# Winrate                  72.12
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.77
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.63
# 2
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35827.95
# Total_Return            258.28
# Annual_Return             4.15
# Time_in_Market           26.00
# Return_By_Exposure       15.96
# Max_Drawdown            -15.04
# Return_Over_Drawdown      0.28
# RBE_Over_Drawdown         1.06
# Signals                1264.00
# Trades                 2065.00
# Gap                      89.00
# No_Gap                 1976.00
# Wins                    454.00
# Losses                  177.00
# Winrate                  71.95
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.77
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.63
# 3
#                            RSI
# Start_Balance         10000.00
# Final_Balance         39366.81
# Total_Return            293.67
# Annual_Return             4.46
# Time_in_Market           27.00
# Return_By_Exposure       16.52
# Max_Drawdown            -15.04
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.10
# Signals                1303.00
# Trades                 2099.00
# Gap                      90.00
# No_Gap                 2009.00
# Wins                    471.00
# Losses                  176.00
# Winrate                  72.80
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.23
# Avg_RR                    0.62
# 4
#                            RSI
# Start_Balance         10000.00
# Final_Balance         40684.74
# Total_Return            306.85
# Annual_Return             4.57
# Time_in_Market           27.00
# Return_By_Exposure       16.93
# Max_Drawdown            -15.51
# Return_Over_Drawdown      0.29
# RBE_Over_Drawdown         1.09
# Signals                1345.00
# Trades                 2134.00
# Gap                      91.00
# No_Gap                 2043.00
# Wins                    480.00
# Losses                  179.00
# Winrate                  72.84
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.62
# 5
#                            RSI
# Start_Balance         10000.00
# Final_Balance         40322.56
# Total_Return            303.23
# Annual_Return             4.54
# Time_in_Market           27.00
# Return_By_Exposure       16.81
# Max_Drawdown            -14.91
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.13
# Signals                1388.00
# Trades                 2165.00
# Gap                      92.00
# No_Gap                 2073.00
# Wins                    485.00
# Losses                  185.00
# Winrate                  72.39
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.21
# Avg_RR                    0.63
# 6
#                            RSI
# Start_Balance         10000.00
# Final_Balance         39452.29
# Total_Return            294.52
# Annual_Return             4.47
# Time_in_Market           28.00
# Return_By_Exposure       15.96
# Max_Drawdown            -14.91
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.07
# Signals                1429.00
# Trades                 2199.00
# Gap                      93.00
# No_Gap                 2106.00
# Wins                    489.00
# Losses                  190.00
# Winrate                  72.02
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.63
# 7
#                            RSI
# Start_Balance         10000.00
# Final_Balance         41179.39
# Total_Return            311.79
# Annual_Return             4.61
# Time_in_Market           29.00
# Return_By_Exposure       15.90
# Max_Drawdown            -14.91
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.07
# Signals                1487.00
# Trades                 2260.00
# Gap                      97.00
# No_Gap                 2163.00
# Wins                    505.00
# Losses                  194.00
# Winrate                  72.25
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.76
# Avg_Trade_Loss_pct       -1.21
# Avg_RR                    0.62
# 8
#                            RSI
# Start_Balance         10000.00
# Final_Balance         40680.88
# Total_Return            306.81
# Annual_Return             4.57
# Time_in_Market           29.00
# Return_By_Exposure       15.76
# Max_Drawdown            -14.91
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.06
# Signals                1529.00
# Trades                 2290.00
# Gap                      99.00
# No_Gap                 2191.00
# Wins                    509.00
# Losses                  194.00
# Winrate                  72.40
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.62
# 9
#                            RSI
# Start_Balance         10000.00
# Final_Balance         42319.66
# Total_Return            323.20
# Annual_Return             4.70
# Time_in_Market           29.00
# Return_By_Exposure       16.21
# Max_Drawdown            -14.91
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.09
# Signals                1580.00
# Trades                 2318.00
# Gap                     101.00
# No_Gap                 2217.00
# Wins                    522.00
# Losses                  198.00
# Winrate                  72.50
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.21
# Avg_RR                    0.62
# 10
#                            RSI
# Start_Balance         10000.00
# Final_Balance         44644.69
# Total_Return            346.45
# Annual_Return             4.88
# Time_in_Market           30.00
# Return_By_Exposure       16.27
# Max_Drawdown            -14.62
# Return_Over_Drawdown      0.33
# RBE_Over_Drawdown         1.11
# Signals                1620.00
# Trades                 2343.00
# Gap                     101.00
# No_Gap                 2242.00
# Wins                    530.00
# Losses                  201.00
# Winrate                  72.50
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.62
# 11
#                            RSI
# Start_Balance         10000.00
# Final_Balance         44779.56
# Total_Return            347.80
# Annual_Return             4.89
# Time_in_Market           30.00
# Return_By_Exposure       16.30
# Max_Drawdown            -14.62
# Return_Over_Drawdown      0.33
# RBE_Over_Drawdown         1.11
# Signals                1679.00
# Trades                 2398.00
# Gap                     105.00
# No_Gap                 2293.00
# Wins                    546.00
# Losses                  206.00
# Winrate                  72.61
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.23
# Avg_RR                    0.61
# 12
#                            RSI
# Start_Balance         10000.00
# Final_Balance         44436.24
# Total_Return            344.36
# Annual_Return             4.86
# Time_in_Market           31.00
# Return_By_Exposure       15.68
# Max_Drawdown            -14.62
# Return_Over_Drawdown      0.33
# RBE_Over_Drawdown         1.07
# Signals                1736.00
# Trades                 2431.00
# Gap                     107.00
# No_Gap                 2324.00
# Wins                    555.00
# Losses                  210.00
# Winrate                  72.55
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.74
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.61
# 13
#                            RSI
# Start_Balance         10000.00
# Final_Balance         41852.19
# Total_Return            318.52
# Annual_Return             4.66
# Time_in_Market           31.00
# Return_By_Exposure       15.03
# Max_Drawdown            -14.41
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.04
# Signals                1797.00
# Trades                 2454.00
# Gap                     107.00
# No_Gap                 2347.00
# Wins                    558.00
# Losses                  216.00
# Winrate                  72.09
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.61
# 14
#                            RSI
# Start_Balance         10000.00
# Final_Balance         42009.91
# Total_Return            320.10
# Annual_Return             4.68
# Time_in_Market           32.00
# Return_By_Exposure       14.62
# Max_Drawdown            -13.66
# Return_Over_Drawdown      0.34
# RBE_Over_Drawdown         1.07
# Signals                1865.00
# Trades                 2498.00
# Gap                     109.00
# No_Gap                 2389.00
# Wins                    572.00
# Losses                  222.00
# Winrate                  72.04
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.61
# 15
#                            RSI
# Start_Balance         10000.00
# Final_Balance         40974.00
# Total_Return            309.74
# Annual_Return             4.59
# Time_in_Market           32.00
# Return_By_Exposure       14.34
# Max_Drawdown            -13.66
# Return_Over_Drawdown      0.34
# RBE_Over_Drawdown         1.05
# Signals                1912.00
# Trades                 2526.00
# Gap                     110.00
# No_Gap                 2416.00
# Wins                    581.00
# Losses                  225.00
# Winrate                  72.08
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.22
# Avg_RR                    0.60
# 16
#                            RSI
# Start_Balance         10000.00
# Final_Balance         41740.77
# Total_Return            317.41
# Annual_Return             4.65
# Time_in_Market           32.00
# Return_By_Exposure       14.53
# Max_Drawdown            -13.16
# Return_Over_Drawdown      0.35
# RBE_Over_Drawdown         1.10
# Signals                1976.00
# Trades                 2568.00
# Gap                     111.00
# No_Gap                 2457.00
# Wins                    597.00
# Losses                  229.00
# Winrate                  72.28
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.25
# Avg_RR                    0.58
# 17
#                            RSI
# Start_Balance         10000.00
# Final_Balance         44167.85
# Total_Return            341.68
# Annual_Return             4.84
# Time_in_Market           33.00
# Return_By_Exposure       14.67
# Max_Drawdown            -13.16
# Return_Over_Drawdown      0.37
# RBE_Over_Drawdown         1.11
# Signals                2030.00
# Trades                 2596.00
# Gap                     114.00
# No_Gap                 2482.00
# Wins                    611.00
# Losses                  229.00
# Winrate                  72.74
# Max_Trade_Return_pct      2.92
# Max_Trade_Loss_pct      -12.32
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.25
# Avg_RR                    0.58
# 18
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33340.19
# Total_Return            233.40
# Annual_Return             3.91
# Time_in_Market           26.00
# Return_By_Exposure       15.04
# Max_Drawdown            -13.13
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.15
# Signals                1227.00
# Trades                 2027.00
# Gap                      86.00
# No_Gap                 1941.00
# Wins                    447.00
# Losses                  174.00
# Winrate                  71.98
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.62
# 19
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35031.74
# Total_Return            250.32
# Annual_Return             4.07
# Time_in_Market           26.00
# Return_By_Exposure       15.65
# Max_Drawdown            -13.13
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.19
# Signals                1279.00
# Trades                 2072.00
# Gap                      90.00
# No_Gap                 1982.00
# Wins                    455.00
# Losses                  179.00
# Winrate                  71.77
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.18
# Avg_RR                    0.64
# 20
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34956.91
# Total_Return            249.57
# Annual_Return             4.06
# Time_in_Market           27.00
# Return_By_Exposure       15.04
# Max_Drawdown            -13.13
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.15
# Signals                1339.00
# Trades                 2115.00
# Gap                      93.00
# No_Gap                 2022.00
# Wins                    471.00
# Losses                  182.00
# Winrate                  72.13
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.74
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.62
# 21
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37906.13
# Total_Return            279.06
# Annual_Return             4.33
# Time_in_Market           27.00
# Return_By_Exposure       16.04
# Max_Drawdown            -13.95
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.15
# Signals                1399.00
# Trades                 2151.00
# Gap                      93.00
# No_Gap                 2058.00
# Wins                    486.00
# Losses                  185.00
# Winrate                  72.43
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.74
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.62
# 22
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36918.39
# Total_Return            269.18
# Annual_Return             4.25
# Time_in_Market           28.00
# Return_By_Exposure       15.18
# Max_Drawdown            -13.49
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.13
# Signals                1472.00
# Trades                 2200.00
# Gap                      97.00
# No_Gap                 2103.00
# Wins                    499.00
# Losses                  191.00
# Winrate                  72.32
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.20
# Avg_RR                    0.61
# 23
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34738.27
# Total_Return            247.38
# Annual_Return             4.04
# Time_in_Market           28.00
# Return_By_Exposure       14.43
# Max_Drawdown            -13.49
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.07
# Signals                1536.00
# Trades                 2246.00
# Gap                     101.00
# No_Gap                 2145.00
# Wins                    508.00
# Losses                  201.00
# Winrate                  71.65
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.19
# Avg_RR                    0.61
# 24
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35741.78
# Total_Return            257.42
# Annual_Return             4.14
# Time_in_Market           29.00
# Return_By_Exposure       14.28
# Max_Drawdown            -13.54
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.05
# Signals                1596.00
# Trades                 2278.00
# Gap                     105.00
# No_Gap                 2173.00
# Wins                    520.00
# Losses                  205.00
# Winrate                  71.72
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.18
# Avg_RR                    0.61
# 25
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37656.84
# Total_Return            276.57
# Annual_Return             4.31
# Time_in_Market           29.00
# Return_By_Exposure       14.86
# Max_Drawdown            -13.54
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.10
# Signals                1656.00
# Trades                 2315.00
# Gap                     106.00
# No_Gap                 2209.00
# Wins                    531.00
# Losses                  209.00
# Winrate                  71.76
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.17
# Avg_RR                    0.62
# 26
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35110.66
# Total_Return            251.11
# Annual_Return             4.08
# Time_in_Market           30.00
# Return_By_Exposure       13.60
# Max_Drawdown            -14.02
# Return_Over_Drawdown      0.29
# RBE_Over_Drawdown         0.97
# Signals                1721.00
# Trades                 2353.00
# Gap                     108.00
# No_Gap                 2245.00
# Wins                    540.00
# Losses                  216.00
# Winrate                  71.43
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.71
# Avg_Trade_Loss_pct       -1.18
# Avg_RR                    0.61
# 27
#                            RSI
# Start_Balance         10000.00
# Final_Balance         38814.16
# Total_Return            288.14
# Annual_Return             4.41
# Time_in_Market           30.00
# Return_By_Exposure       14.70
# Max_Drawdown            -14.02
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.05
# Signals                1799.00
# Trades                 2404.00
# Gap                     115.00
# No_Gap                 2289.00
# Wins                    562.00
# Losses                  224.00
# Winrate                  71.50
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.71
# Avg_Trade_Loss_pct       -1.14
# Avg_RR                    0.62
# 28
#                            RSI
# Start_Balance         10000.00
# Final_Balance         42107.16
# Total_Return            321.07
# Annual_Return             4.68
# Time_in_Market           31.00
# Return_By_Exposure       15.10
# Max_Drawdown            -14.02
# Return_Over_Drawdown      0.33
# RBE_Over_Drawdown         1.08
# Signals                1862.00
# Trades                 2438.00
# Gap                     118.00
# No_Gap                 2320.00
# Wins                    580.00
# Losses                  229.00
# Winrate                  71.69
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.12
# Avg_RR                    0.62
# 29
#                            RSI
# Start_Balance         10000.00
# Final_Balance         43547.05
# Total_Return            335.47
# Annual_Return             4.80
# Time_in_Market           31.00
# Return_By_Exposure       15.48
# Max_Drawdown            -14.20
# Return_Over_Drawdown      0.34
# RBE_Over_Drawdown         1.09
# Signals                1913.00
# Trades                 2458.00
# Gap                     120.00
# No_Gap                 2338.00
# Wins                    587.00
# Losses                  234.00
# Winrate                  71.50
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.11
# Avg_RR                    0.63
# 30
#                            RSI
# Start_Balance         10000.00
# Final_Balance         45116.66
# Total_Return            351.17
# Annual_Return             4.91
# Time_in_Market           32.00
# Return_By_Exposure       15.34
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.36
# RBE_Over_Drawdown         1.13
# Signals                1979.00
# Trades                 2499.00
# Gap                     122.00
# No_Gap                 2377.00
# Wins                    600.00
# Losses                  242.00
# Winrate                  71.26
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.08
# Avg_RR                    0.64
# 31
#                            RSI
# Start_Balance         10000.00
# Final_Balance         48475.88
# Total_Return            384.76
# Annual_Return             5.15
# Time_in_Market           32.00
# Return_By_Exposure       16.09
# Max_Drawdown            -14.27
# Return_Over_Drawdown      0.36
# RBE_Over_Drawdown         1.13
# Signals                2041.00
# Trades                 2523.00
# Gap                     124.00
# No_Gap                 2399.00
# Wins                    615.00
# Losses                  246.00
# Winrate                  71.43
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.08
# Avg_RR                    0.65
# 32
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36544.20
# Total_Return            265.44
# Annual_Return             4.21
# Time_in_Market           32.00
# Return_By_Exposure       13.16
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.45
# Signals                2107.00
# Trades                 2565.00
# Gap                     129.00
# No_Gap                 2436.00
# Wins                    619.00
# Losses                  254.00
# Winrate                  70.90
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.16
# Avg_RR                    0.60
# 33
#                            RSI
# Start_Balance         10000.00
# Final_Balance         39111.44
# Total_Return            291.11
# Annual_Return             4.44
# Time_in_Market           33.00
# Return_By_Exposure       13.45
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.46
# Signals                2160.00
# Trades                 2594.00
# Gap                     131.00
# No_Gap                 2463.00
# Wins                    632.00
# Losses                  261.00
# Winrate                  70.77
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.14
# Avg_RR                    0.62
# 34
#                            RSI
# Start_Balance         10000.00
# Final_Balance         41197.38
# Total_Return            311.97
# Annual_Return             4.61
# Time_in_Market           33.00
# Return_By_Exposure       13.97
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.16
# RBE_Over_Drawdown         0.48
# Signals                2208.00
# Trades                 2616.00
# Gap                     131.00
# No_Gap                 2485.00
# Wins                    644.00
# Losses                  267.00
# Winrate                  70.69
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.12
# Avg_RR                    0.62
# 35
#                            RSI
# Start_Balance         10000.00
# Final_Balance         39772.41
# Total_Return            297.72
# Annual_Return             4.49
# Time_in_Market           33.00
# Return_By_Exposure       13.61
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.47
# Signals                2252.00
# Trades                 2643.00
# Gap                     133.00
# No_Gap                 2510.00
# Wins                    649.00
# Losses                  273.00
# Winrate                  70.39
# Max_Trade_Return_pct      3.00
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.12
# Avg_RR                    0.62
# 36
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33631.71
# Total_Return            236.32
# Annual_Return             3.94
# Time_in_Market           26.00
# Return_By_Exposure       15.15
# Max_Drawdown            -13.13
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.15
# Signals                1293.00
# Trades                 2092.00
# Gap                      90.00
# No_Gap                 2002.00
# Wins                    459.00
# Losses                  182.00
# Winrate                  71.61
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.75
# Avg_Trade_Loss_pct       -1.19
# Avg_RR                    0.63
# 37
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36440.30
# Total_Return            264.40
# Annual_Return             4.20
# Time_in_Market           27.00
# Return_By_Exposure       15.56
# Max_Drawdown            -13.95
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.12
# Signals                1381.00
# Trades                 2140.00
# Gap                      94.00
# No_Gap                 2046.00
# Wins                    481.00
# Losses                  185.00
# Winrate                  72.22
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.74
# Avg_Trade_Loss_pct       -1.19
# Avg_RR                    0.62
# 38
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34461.97
# Total_Return            244.62
# Annual_Return             4.02
# Time_in_Market           28.00
# Return_By_Exposure       14.36
# Max_Drawdown            -13.95
# Return_Over_Drawdown      0.29
# RBE_Over_Drawdown         1.03
# Signals                1478.00
# Trades                 2208.00
# Gap                      99.00
# No_Gap                 2109.00
# Wins                    497.00
# Losses                  196.00
# Winrate                  71.72
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.73
# Avg_Trade_Loss_pct       -1.18
# Avg_RR                    0.61
# 39
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35414.81
# Total_Return            254.15
# Annual_Return             4.11
# Time_in_Market           29.00
# Return_By_Exposure       14.17
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.05
# Signals                1557.00
# Trades                 2256.00
# Gap                     105.00
# No_Gap                 2151.00
# Wins                    514.00
# Losses                  203.00
# Winrate                  71.69
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.17
# Avg_RR                    0.61
# 40
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37292.20
# Total_Return            272.92
# Annual_Return             4.28
# Time_in_Market           29.00
# Return_By_Exposure       14.76
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.09
# Signals                1638.00
# Trades                 2306.00
# Gap                     107.00
# No_Gap                 2199.00
# Wins                    533.00
# Losses                  208.00
# Winrate                  71.93
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.71
# Avg_Trade_Loss_pct       -1.16
# Avg_RR                    0.61
# 41
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35646.96
# Total_Return            256.47
# Annual_Return             4.13
# Time_in_Market           30.00
# Return_By_Exposure       13.77
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.02
# Signals                1730.00
# Trades                 2369.00
# Gap                     114.00
# No_Gap                 2255.00
# Wins                    549.00
# Losses                  222.00
# Winrate                  71.21
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.14
# Avg_RR                    0.62
# 42
#                            RSI
# Start_Balance         10000.00
# Final_Balance         42464.08
# Total_Return            324.64
# Annual_Return             4.71
# Time_in_Market           30.00
# Return_By_Exposure       15.70
# Max_Drawdown            -13.42
# Return_Over_Drawdown      0.35
# RBE_Over_Drawdown         1.17
# Signals                1810.00
# Trades                 2409.00
# Gap                     116.00
# No_Gap                 2293.00
# Wins                    577.00
# Losses                  227.00
# Winrate                  71.77
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.11
# Avg_RR                    0.63
# 43
#                            RSI
# Start_Balance         10000.00
# Final_Balance         40660.48
# Total_Return            306.60
# Annual_Return             4.57
# Time_in_Market           31.00
# Return_By_Exposure       14.74
# Max_Drawdown            -13.60
# Return_Over_Drawdown      0.34
# RBE_Over_Drawdown         1.08
# Signals                1876.00
# Trades                 2447.00
# Gap                     120.00
# No_Gap                 2327.00
# Wins                    583.00
# Losses                  238.00
# Winrate                  71.01
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.70
# Avg_Trade_Loss_pct       -1.09
# Avg_RR                    0.64
# 44
#                            RSI
# Start_Balance         10000.00
# Final_Balance         41304.66
# Total_Return            313.05
# Annual_Return             4.62
# Time_in_Market           31.00
# Return_By_Exposure       14.90
# Max_Drawdown            -13.15
# Return_Over_Drawdown      0.35
# RBE_Over_Drawdown         1.13
# Signals                1941.00
# Trades                 2481.00
# Gap                     124.00
# No_Gap                 2357.00
# Wins                    594.00
# Losses                  248.00
# Winrate                  70.55
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.06
# Avg_RR                    0.65
# 45
#                            RSI
# Start_Balance         10000.00
# Final_Balance         30707.38
# Total_Return            207.07
# Annual_Return             3.64
# Time_in_Market           32.00
# Return_By_Exposure       11.38
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.39
# Signals                2006.00
# Trades                 2530.00
# Gap                     130.00
# No_Gap                 2400.00
# Wins                    597.00
# Losses                  259.00
# Winrate                  69.74
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.13
# Avg_RR                    0.61
# 46
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32136.00
# Total_Return            221.36
# Annual_Return             3.79
# Time_in_Market           32.00
# Return_By_Exposure       11.84
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.41
# Signals                2067.00
# Trades                 2565.00
# Gap                     134.00
# No_Gap                 2431.00
# Wins                    613.00
# Losses                  269.00
# Winrate                  69.50
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.10
# Avg_RR                    0.62
# 47
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32624.72
# Total_Return            226.25
# Annual_Return             3.84
# Time_in_Market           33.00
# Return_By_Exposure       11.64
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.40
# Signals                2109.00
# Trades                 2591.00
# Gap                     137.00
# No_Gap                 2454.00
# Wins                    623.00
# Losses                  276.00
# Winrate                  69.30
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.09
# Avg_RR                    0.63
# 48
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33047.18
# Total_Return            230.47
# Annual_Return             3.88
# Time_in_Market           33.00
# Return_By_Exposure       11.76
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.40
# Signals                2149.00
# Trades                 2620.00
# Gap                     140.00
# No_Gap                 2480.00
# Wins                    632.00
# Losses                  281.00
# Winrate                  69.22
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.08
# Avg_RR                    0.63
# 49
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32375.72
# Total_Return            223.76
# Annual_Return             3.81
# Time_in_Market           33.00
# Return_By_Exposure       11.55
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.40
# Signals                2200.00
# Trades                 2646.00
# Gap                     140.00
# No_Gap                 2506.00
# Wins                    637.00
# Losses                  292.00
# Winrate                  68.57
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.06
# Avg_RR                    0.65
# 50
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34382.14
# Total_Return            243.82
# Annual_Return             4.01
# Time_in_Market           34.00
# Return_By_Exposure       11.79
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.41
# Signals                2253.00
# Trades                 2665.00
# Gap                     141.00
# No_Gap                 2524.00
# Wins                    646.00
# Losses                  299.00
# Winrate                  68.36
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.03
# Avg_RR                    0.66
# 51
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36177.37
# Total_Return            261.77
# Annual_Return             4.18
# Time_in_Market           34.00
# Return_By_Exposure       12.29
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.43
# Signals                2304.00
# Trades                 2688.00
# Gap                     141.00
# No_Gap                 2547.00
# Wins                    659.00
# Losses                  305.00
# Winrate                  68.36
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.02
# Avg_RR                    0.67
# 52
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37676.58
# Total_Return            276.77
# Annual_Return             4.31
# Time_in_Market           34.00
# Return_By_Exposure       12.68
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.44
# Signals                2342.00
# Trades                 2705.00
# Gap                     144.00
# No_Gap                 2561.00
# Wins                    668.00
# Losses                  310.00
# Winrate                  68.30
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.01
# Avg_RR                    0.68
# 53
#                            RSI
# Start_Balance         10000.00
# Final_Balance         38397.30
# Total_Return            283.97
# Annual_Return             4.38
# Time_in_Market           34.00
# Return_By_Exposure       12.88
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.45
# Signals                2379.00
# Trades                 2730.00
# Gap                     147.00
# No_Gap                 2583.00
# Wins                    681.00
# Losses                  314.00
# Winrate                  68.44
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.67
# Avg_Trade_Loss_pct       -1.00
# Avg_RR                    0.67
# 54
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36439.87
# Total_Return            264.40
# Annual_Return             4.20
# Time_in_Market           27.00
# Return_By_Exposure       15.56
# Max_Drawdown            -13.95
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.12
# Signals                1369.00
# Trades                 2136.00
# Gap                      93.00
# No_Gap                 2043.00
# Wins                    479.00
# Losses                  185.00
# Winrate                  72.14
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.74
# Avg_Trade_Loss_pct       -1.19
# Avg_RR                    0.62
# 55
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33455.31
# Total_Return            234.55
# Annual_Return             3.92
# Time_in_Market           28.00
# Return_By_Exposure       14.00
# Max_Drawdown            -13.95
# Return_Over_Drawdown      0.28
# RBE_Over_Drawdown         1.00
# Signals                1496.00
# Trades                 2225.00
# Gap                     101.00
# No_Gap                 2124.00
# Wins                    500.00
# Losses                  200.00
# Winrate                  71.43
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.72
# Avg_Trade_Loss_pct       -1.18
# Avg_RR                    0.61
# 56
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35539.22
# Total_Return            255.39
# Annual_Return             4.12
# Time_in_Market           29.00
# Return_By_Exposure       14.21
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.30
# RBE_Over_Drawdown         1.05
# Signals                1593.00
# Trades                 2285.00
# Gap                     106.00
# No_Gap                 2179.00
# Wins                    520.00
# Losses                  208.00
# Winrate                  71.43
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.71
# Avg_Trade_Loss_pct       -1.15
# Avg_RR                    0.62
# 57
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35600.73
# Total_Return            256.01
# Annual_Return             4.13
# Time_in_Market           30.00
# Return_By_Exposure       13.77
# Max_Drawdown            -13.53
# Return_Over_Drawdown      0.31
# RBE_Over_Drawdown         1.02
# Signals                1704.00
# Trades                 2357.00
# Gap                     114.00
# No_Gap                 2243.00
# Wins                    543.00
# Losses                  221.00
# Winrate                  71.07
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.71
# Avg_Trade_Loss_pct       -1.13
# Avg_RR                    0.62
# 58
#                            RSI
# Start_Balance         10000.00
# Final_Balance         38992.28
# Total_Return            289.92
# Annual_Return             4.43
# Time_in_Market           30.00
# Return_By_Exposure       14.77
# Max_Drawdown            -13.60
# Return_Over_Drawdown      0.33
# RBE_Over_Drawdown         1.09
# Signals                1802.00
# Trades                 2407.00
# Gap                     117.00
# No_Gap                 2290.00
# Wins                    569.00
# Losses                  232.00
# Winrate                  71.04
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.09
# Avg_RR                    0.64
# 59
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37586.16
# Total_Return            275.86
# Annual_Return             4.31
# Time_in_Market           31.00
# Return_By_Exposure       13.90
# Max_Drawdown            -13.50
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         1.03
# Signals                1878.00
# Trades                 2457.00
# Gap                     123.00
# No_Gap                 2334.00
# Wins                    580.00
# Losses                  245.00
# Winrate                  70.30
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.07
# Avg_RR                    0.65
# 60
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37083.76
# Total_Return            270.84
# Annual_Return             4.26
# Time_in_Market           32.00
# Return_By_Exposure       13.31
# Max_Drawdown            -13.50
# Return_Over_Drawdown      0.32
# RBE_Over_Drawdown         0.99
# Signals                1960.00
# Trades                 2501.00
# Gap                     128.00
# No_Gap                 2373.00
# Wins                    589.00
# Losses                  255.00
# Winrate                  69.79
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -11.96
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.05
# Avg_RR                    0.65
# 61
#                            RSI
# Start_Balance         10000.00
# Final_Balance         29933.48
# Total_Return            199.33
# Annual_Return             3.55
# Time_in_Market           32.00
# Return_By_Exposure       11.09
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.12
# RBE_Over_Drawdown         0.38
# Signals                2030.00
# Trades                 2554.00
# Gap                     134.00
# No_Gap                 2420.00
# Wins                    605.00
# Losses                  268.00
# Winrate                  69.30
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.69
# Avg_Trade_Loss_pct       -1.10
# Avg_RR                    0.62
# 62
#                            RSI
# Start_Balance         10000.00
# Final_Balance         30641.23
# Total_Return            206.41
# Annual_Return             3.63
# Time_in_Market           33.00
# Return_By_Exposure       11.00
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.12
# RBE_Over_Drawdown         0.38
# Signals                2077.00
# Trades                 2581.00
# Gap                     136.00
# No_Gap                 2445.00
# Wins                    618.00
# Losses                  276.00
# Winrate                  69.13
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.09
# Avg_RR                    0.63
# 63
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32525.25
# Total_Return            225.25
# Annual_Return             3.83
# Time_in_Market           33.00
# Return_By_Exposure       11.61
# Max_Drawdown            -29.10
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.40
# Signals                2125.00
# Trades                 2614.00
# Gap                     140.00
# No_Gap                 2474.00
# Wins                    633.00
# Losses                  283.00
# Winrate                  69.10
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.07
# Avg_RR                    0.63
# 64
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34334.06
# Total_Return            243.34
# Annual_Return             4.01
# Time_in_Market           33.00
# Return_By_Exposure       12.15
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.42
# Signals                2172.00
# Trades                 2632.00
# Gap                     139.00
# No_Gap                 2493.00
# Wins                    643.00
# Losses                  290.00
# Winrate                  68.92
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.05
# Avg_RR                    0.65
# 65
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33832.41
# Total_Return            238.32
# Annual_Return             3.96
# Time_in_Market           34.00
# Return_By_Exposure       11.65
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.40
# Signals                2239.00
# Trades                 2663.00
# Gap                     142.00
# No_Gap                 2521.00
# Wins                    650.00
# Losses                  305.00
# Winrate                  68.06
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.01
# Avg_RR                    0.67
# 66
#                            RSI
# Start_Balance         10000.00
# Final_Balance         35034.22
# Total_Return            250.34
# Annual_Return             4.07
# Time_in_Market           34.00
# Return_By_Exposure       11.97
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.42
# Signals                2280.00
# Trades                 2684.00
# Gap                     144.00
# No_Gap                 2540.00
# Wins                    661.00
# Losses                  311.00
# Winrate                  68.00
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.67
# Avg_Trade_Loss_pct       -1.00
# Avg_RR                    0.67
# 67
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34987.20
# Total_Return            249.87
# Annual_Return             4.07
# Time_in_Market           34.00
# Return_By_Exposure       11.97
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.42
# Signals                2312.00
# Trades                 2700.00
# Gap                     145.00
# No_Gap                 2555.00
# Wins                    670.00
# Losses                  316.00
# Winrate                  67.95
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.67
# Avg_Trade_Loss_pct       -0.99
# Avg_RR                    0.68
# 68
#                            RSI
# Start_Balance         10000.00
# Final_Balance         36707.64
# Total_Return            267.08
# Annual_Return             4.23
# Time_in_Market           34.00
# Return_By_Exposure       12.44
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.43
# Signals                2348.00
# Trades                 2718.00
# Gap                     149.00
# No_Gap                 2569.00
# Wins                    680.00
# Losses                  321.00
# Winrate                  67.93
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.67
# Avg_Trade_Loss_pct       -0.98
# Avg_RR                    0.68
# 69
#                            RSI
# Start_Balance         10000.00
# Final_Balance         37142.67
# Total_Return            271.43
# Annual_Return             4.27
# Time_in_Market           34.00
# Return_By_Exposure       12.56
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.15
# RBE_Over_Drawdown         0.44
# Signals                2378.00
# Trades                 2728.00
# Gap                     150.00
# No_Gap                 2578.00
# Wins                    684.00
# Losses                  323.00
# Winrate                  67.92
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.67
# Avg_Trade_Loss_pct       -0.97
# Avg_RR                    0.68
# 70
#                            RSI
# ...
# Losses                  379.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 409
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32138.83
# Total_Return            221.39
# Annual_Return             3.79
# Time_in_Market           36.00
# Return_By_Exposure       10.53
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2556.00
# Trades                 2881.00
# Gap                     167.00
# No_Gap                 2714.00
# Wins                    743.00
# Losses                  379.00
# Winrate                  66.22
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.69
# 410
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32481.02
# Total_Return            224.81
# Annual_Return             3.82
# Time_in_Market           36.00
# Return_By_Exposure       10.61
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2562.00
# Trades                 2885.00
# Gap                     168.00
# No_Gap                 2717.00
# Wins                    745.00
# Losses                  380.00
# Winrate                  66.22
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 411
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32443.19
# Total_Return            224.43
# Annual_Return             3.82
# Time_in_Market           36.00
# Return_By_Exposure       10.61
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2566.00
# Trades                 2887.00
# Gap                     168.00
# No_Gap                 2719.00
# Wins                    746.00
# Losses                  381.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 412
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32326.40
# Total_Return            223.26
# Annual_Return             3.81
# Time_in_Market           37.00
# Return_By_Exposure       10.30
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.37
# Signals                2571.00
# Trades                 2889.00
# Gap                     170.00
# No_Gap                 2719.00
# Wins                    747.00
# Losses                  382.00
# Winrate                  66.16
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 413
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32398.75
# Total_Return            223.99
# Annual_Return             3.81
# Time_in_Market           37.00
# Return_By_Exposure       10.30
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.37
# Signals                2574.00
# Trades                 2890.00
# Gap                     170.00
# No_Gap                 2720.00
# Wins                    748.00
# Losses                  382.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 414
#                            RSI
# Start_Balance         10000.00
# Final_Balance         31605.48
# Total_Return            216.05
# Annual_Return             3.73
# Time_in_Market           33.00
# Return_By_Exposure       11.30
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.39
# Signals                2167.00
# Trades                 2641.00
# Gap                     141.00
# No_Gap                 2500.00
# Wins                    637.00
# Losses                  303.00
# Winrate                  67.77
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.68
# Avg_Trade_Loss_pct       -1.01
# Avg_RR                    0.67
# 415
#                            RSI
# Start_Balance         10000.00
# Final_Balance         34694.14
# Total_Return            246.94
# Annual_Return             4.04
# Time_in_Market           34.00
# Return_By_Exposure       11.88
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.41
# Signals                2293.00
# Trades                 2706.00
# Gap                     149.00
# No_Gap                 2557.00
# Wins                    674.00
# Losses                  324.00
# Winrate                  67.54
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.66
# Avg_Trade_Loss_pct       -0.96
# Avg_RR                    0.69
# 416
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33304.14
# Total_Return            233.04
# Annual_Return             3.90
# Time_in_Market           35.00
# Return_By_Exposure       11.14
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.39
# Signals                2364.00
# Trades                 2752.00
# Gap                     154.00
# No_Gap                 2598.00
# Wins                    692.00
# Losses                  338.00
# Winrate                  67.18
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.65
# Avg_Trade_Loss_pct       -0.95
# Avg_RR                    0.69
# 417
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32933.01
# Total_Return            229.33
# Annual_Return             3.87
# Time_in_Market           35.00
# Return_By_Exposure       11.06
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.38
# Signals                2408.00
# Trades                 2791.00
# Gap                     155.00
# No_Gap                 2636.00
# Wins                    709.00
# Losses                  346.00
# Winrate                  67.20
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.65
# Avg_Trade_Loss_pct       -0.96
# Avg_RR                    0.68
# 418
#                            RSI
# Start_Balance         10000.00
# Final_Balance         33186.89
# Total_Return            231.87
# Annual_Return             3.89
# Time_in_Market           36.00
# Return_By_Exposure       10.81
# Max_Drawdown            -28.83
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.37
# Signals                2444.00
# Trades                 2810.00
# Gap                     159.00
# No_Gap                 2651.00
# Wins                    718.00
# Losses                  353.00
# Winrate                  67.04
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.65
# Avg_Trade_Loss_pct       -0.95
# Avg_RR                    0.68
# 419
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32004.78
# Total_Return            220.05
# Annual_Return             3.77
# Time_in_Market           36.00
# Return_By_Exposure       10.47
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.37
# Signals                2472.00
# Trades                 2830.00
# Gap                     159.00
# No_Gap                 2671.00
# Wins                    724.00
# Losses                  360.00
# Winrate                  66.79
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.65
# Avg_Trade_Loss_pct       -0.95
# Avg_RR                    0.68
# 420
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32286.37
# Total_Return            222.86
# Annual_Return             3.80
# Time_in_Market           36.00
# Return_By_Exposure       10.56
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2490.00
# Trades                 2844.00
# Gap                     160.00
# No_Gap                 2684.00
# Wins                    728.00
# Losses                  365.00
# Winrate                  66.61
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.94
# Avg_RR                    0.69
# 421
#                            RSI
# Start_Balance         10000.00
# Final_Balance         31823.53
# Total_Return            218.24
# Annual_Return             3.75
# Time_in_Market           36.00
# Return_By_Exposure       10.42
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.37
# Signals                2506.00
# Trades                 2855.00
# Gap                     162.00
# No_Gap                 2693.00
# Wins                    733.00
# Losses                  367.00
# Winrate                  66.64
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.94
# Avg_RR                    0.68
# 422
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32171.37
# Total_Return            221.71
# Annual_Return             3.79
# Time_in_Market           36.00
# Return_By_Exposure       10.53
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2518.00
# Trades                 2862.00
# Gap                     164.00
# No_Gap                 2698.00
# Wins                    737.00
# Losses                  370.00
# Winrate                  66.58
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.94
# Avg_RR                    0.69
# 423
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32453.74
# Total_Return            224.54
# Annual_Return             3.82
# Time_in_Market           36.00
# Return_By_Exposure       10.61
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2531.00
# Trades                 2868.00
# Gap                     165.00
# No_Gap                 2703.00
# Wins                    739.00
# Losses                  372.00
# Winrate                  66.52
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.93
# Avg_RR                    0.69
# 424
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32110.79
# Total_Return            221.11
# Annual_Return             3.78
# Time_in_Market           36.00
# Return_By_Exposure       10.50
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2540.00
# Trades                 2877.00
# Gap                     166.00
# No_Gap                 2711.00
# Wins                    740.00
# Losses                  378.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.93
# Avg_RR                    0.70
# 425
#                            RSI
# Start_Balance         10000.00
# Final_Balance         31979.53
# Total_Return            219.80
# Annual_Return             3.77
# Time_in_Market           36.00
# Return_By_Exposure       10.47
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.13
# RBE_Over_Drawdown         0.37
# Signals                2548.00
# Trades                 2878.00
# Gap                     166.00
# No_Gap                 2712.00
# Wins                    740.00
# Losses                  379.00
# Winrate                  66.13
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 426
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32109.68
# Total_Return            221.10
# Annual_Return             3.78
# Time_in_Market           36.00
# Return_By_Exposure       10.50
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2553.00
# Trades                 2880.00
# Gap                     167.00
# No_Gap                 2713.00
# Wins                    742.00
# Losses                  379.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 427
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32325.56
# Total_Return            223.26
# Annual_Return             3.81
# Time_in_Market           36.00
# Return_By_Exposure       10.58
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2559.00
# Trades                 2884.00
# Gap                     168.00
# No_Gap                 2716.00
# Wins                    744.00
# Losses                  380.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 428
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32415.26
# Total_Return            224.15
# Annual_Return             3.81
# Time_in_Market           36.00
# Return_By_Exposure       10.58
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2564.00
# Trades                 2886.00
# Gap                     168.00
# No_Gap                 2718.00
# Wins                    745.00
# Losses                  381.00
# Winrate                  66.16
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 429
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32443.19
# Total_Return            224.43
# Annual_Return             3.82
# Time_in_Market           36.00
# Return_By_Exposure       10.61
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.38
# Signals                2566.00
# Trades                 2887.00
# Gap                     168.00
# No_Gap                 2719.00
# Wins                    746.00
# Losses                  381.00
# Winrate                  66.19
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 430
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32342.90
# Total_Return            223.43
# Annual_Return             3.81
# Time_in_Market           37.00
# Return_By_Exposure       10.30
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.37
# Signals                2571.00
# Trades                 2890.00
# Gap                     170.00
# No_Gap                 2720.00
# Wins                    747.00
# Losses                  382.00
# Winrate                  66.16
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
# 431
#                            RSI
# Start_Balance         10000.00
# Final_Balance         32516.27
# Total_Return            225.16
# Annual_Return             3.83
# Time_in_Market           37.00
# Return_By_Exposure       10.35
# Max_Drawdown            -27.97
# Return_Over_Drawdown      0.14
# RBE_Over_Drawdown         0.37
# Signals                2575.00
# Trades                 2891.00
# Gap                     171.00
# No_Gap                 2720.00
# Wins                    749.00
# Losses                  382.00
# Winrate                  66.22
# Max_Trade_Return_pct      3.62
# Max_Trade_Loss_pct      -21.81
# Avg_Trade_Return_pct      0.64
# Avg_Trade_Loss_pct       -0.92
# Avg_RR                    0.70
